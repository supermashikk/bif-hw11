# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/s-a-nersisyan/HSE_bioinformatics_2021/master/seminar11/breast_cancer_key_genes.tsv', sep = '\t', index_col = 0)

sns.kdeplot(x = df['ESR1'], y = df['PGR'],color = 'orange')
plt.tight_layout()
